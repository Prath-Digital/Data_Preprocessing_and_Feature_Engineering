# %% [markdown]
# # 🧪 Lab Work - 2.1
# ---

# %% [markdown]
# ## Q1 - Missing Values Handling (Basic)

# %%
import pandas as pd
import numpy as np

# Create sample dataset
data = {
    'Age': [22, np.nan, 24, 35, np.nan],
    'Fare': [7.25, 71.83, np.nan, 8.05, 10.5],
    'Gender': ['Male', 'Female', np.nan, 'Female', 'Male']
}

df = pd.DataFrame(data)
print('Original Dataset:')
print(df)

# Check missing values
print('\nMissing Values Count:')
print(df.isnull().sum())

# Drop rows with too many missing values
df_clean = df.dropna(thresh=2)
print('\nAfter Dropping Rows:')
print(df_clean)

# Fill missing values
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

print('\nAfter Imputation:')
print(df)
# Out:
# Original Dataset:
#     Age   Fare  Gender
# 0  22.0   7.25    Male
# 1   NaN  71.83  Female
# 2  24.0    NaN     NaN
# 3  35.0   8.05  Female
# 4   NaN  10.50    Male
#
# Missing Values Count:
# Age       2
# Fare      1
# Gender    1
# dtype: int64
#
# After Dropping Rows:
#     Age   Fare  Gender
# 0  22.0   7.25    Male
# 1   NaN  71.83  Female
# 3  35.0   8.05  Female
# 4   NaN  10.50    Male
#
# After Imputation:
#     Age    Fare  Gender
# 0  22.0   7.250    Male
# 1  27.0  71.830  Female
# 2  24.0   9.275  Female
# 3  35.0   8.050  Female
# 4  27.0  10.500    Male
# C:\Users\Dell\AppData\Local\Temp\ipykernel_28868\3193068471.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_28868\3193068471.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(), inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_28868\3193068471.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %% [markdown]
# ## Q2 - SimpleImputer (Numeric Data)

# %%
from sklearn.impute import SimpleImputer

# Create numeric dataset
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2, 3, 4, np.nan]
}

df = pd.DataFrame(data)
print('Original Data:')
print(df)

# Mean Imputation
mean_imputer = SimpleImputer(strategy='mean')
df_mean = pd.DataFrame(mean_imputer.fit_transform(df), columns=df.columns)

print('\nAfter Mean Imputation:')
print(df_mean)

# Median Imputation
median_imputer = SimpleImputer(strategy='median')
df_median = pd.DataFrame(median_imputer.fit_transform(df), columns=df.columns)

print('\nAfter Median Imputation:')
print(df_median)
# Out:
# Original Data:
#      A    B
# 0  1.0  NaN
# 1  2.0  2.0
# 2  NaN  3.0
# 3  4.0  4.0
# 4  5.0  NaN
#
# After Mean Imputation:
#      A    B
# 0  1.0  3.0
# 1  2.0  2.0
# 2  3.0  3.0
# 3  4.0  4.0
# 4  5.0  3.0
#
# After Median Imputation:
#      A    B
# 0  1.0  3.0
# 1  2.0  2.0
# 2  3.0  3.0
# 3  4.0  4.0
# 4  5.0  3.0

# %% [markdown]
# ## Q3 - Categorical Imputation

# %%
# Create categorical dataset
data = {
    'Gender': ['Male', 'Female', np.nan, 'Female', np.nan],
    'Department': ['HR', np.nan, 'IT', 'IT', np.nan]
}

df = pd.DataFrame(data)
print('Original Data:')
print(df)

# Most frequent (mode)
mode_imputer = SimpleImputer(strategy='most_frequent')
df_mode = pd.DataFrame(mode_imputer.fit_transform(df), columns=df.columns)

print('\nAfter Mode Imputation:')
print(df_mode)

# Constant replacement
constant_imputer = SimpleImputer(strategy='constant', fill_value='Unknown')
df_constant = pd.DataFrame(constant_imputer.fit_transform(df), columns=df.columns)

print('\nAfter Constant Imputation:')
print(df_constant)
# Out:
# Original Data:
#    Gender Department
# 0    Male         HR
# 1  Female        NaN
# 2     NaN         IT
# 3  Female         IT
# 4     NaN        NaN
#
# After Mode Imputation:
#    Gender Department
# 0    Male         HR
# 1  Female         IT
# 2  Female         IT
# 3  Female         IT
# 4  Female         IT
#
# After Constant Imputation:
#     Gender Department
# 0     Male         HR
# 1   Female    Unknown
# 2  Unknown         IT
# 3   Female         IT
# 4  Unknown    Unknown

# %% [markdown]
# ## Q4 - Categorical Dataset Comparison

# %%
# Dataset with Cities
data = {
    'City': ['Delhi', 'Mumbai', np.nan, np.nan, 'Delhi']
}

df = pd.DataFrame(data)
print('Original Data:')
print(df)

# Most Frequent
mf_imputer = SimpleImputer(strategy='most_frequent')
df_mf = pd.DataFrame(mf_imputer.fit_transform(df), columns=df.columns)

print('\nMost Frequent Imputation:')
print(df_mf)

# Constant
const_imputer = SimpleImputer(strategy='constant', fill_value='Unknown')
df_const = pd.DataFrame(const_imputer.fit_transform(df), columns=df.columns)

print('\nConstant Imputation:')
print(df_const)
# Out:
# Original Data:
#      City
# 0   Delhi
# 1  Mumbai
# 2     NaN
# 3     NaN
# 4   Delhi
#
# Most Frequent Imputation:
#      City
# 0   Delhi
# 1  Mumbai
# 2   Delhi
# 3   Delhi
# 4   Delhi
#
# Constant Imputation:
#       City
# 0    Delhi
# 1   Mumbai
# 2  Unknown
# 3  Unknown
# 4    Delhi
